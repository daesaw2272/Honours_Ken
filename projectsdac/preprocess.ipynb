# %%
soc_home_activity_cols = [
    "_merge"
]

# %%
import pandas as pd

# %%
df = pd.read_csv("sdac2018processed.csv")

# %%
df = df.drop(columns=soc_home_activity_cols)

# %%
df.to_csv(
    "sdac2018processed.csv",
    index=False
)

# %%
print(df.columns.tolist())
# Out:
# ['ABSPID', 'ABSFID', 'ABSHID', 'ABSIID', 'POPESTAB', 'RECLPSN', 'FINWTP', 'AGEPC', 'SEX', 'EDLVLATB', 'ARIAC', 'SPENGPRO', 'SOCMORCO', 'K10CATEG', 'DISBSTAT', 'SFHEALTH', 'RASFRICO', 'RASFRIMO', 'RASFRISC', 'RASFRIEM', 'RASFRIHC', 'RASFRIHO', 'RASFRIME', 'RASFRIPM', 'RASFRIPA', 'RASFRITR', 'WHNASMOB', 'RASEXMOB', 'WHNASSCR', 'RASEXSC', 'WHNASCOM', 'RASEXCOM', 'NAHCFCAR', 'RASEXHC', 'WHNASEMO', 'RASEXGUI', 'WHNASHOM', 'RASEXHOM', 'WHNASPRO', 'RASEXPRP', 'WNASMEAL', 'RASEXMEA', 'WHNASFIN', 'RASEXPAP', 'NASTRANS', 'RASEXTRA', 'WPM0101', 'WPM0102', 'WPM0103', 'WPM0104', 'WPM0105', 'WPM0106', 'WPM0107', 'WPM0108', 'WPM0109', 'WPM0110', 'WPM0111', 'WPM0112', 'WPM0113', 'WPM0114', 'WPM0115', 'WPM0116', 'WPM0117', 'WPM0118', 'WPM0119', 'WPM0120', 'WPM0121', 'WPM0122', 'WPM0123', 'WPM0124', 'WPM0125', 'WPM0126', 'WPM0127', 'WPM0128', 'WPM0129', 'WPM0130', 'WPM0131', 'WPM0132', 'WPM0133', 'WPM0134', 'WPM0135', 'WPM0136', 'WPM0137', 'WPM0138', 'WPM0139', 'WPM0140', 'WPM0141', 'WPM0142', 'WPM014
# ...
