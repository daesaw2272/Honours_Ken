# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("sdac2018_candidate_variables_raw.csv")

# %%
need_vars = [
    "WHNASMOB",
    "WHNASSCR",
    "WHNASCOM",
    "NAHCFCAR",
    "WHNASEMO",
    "WHNASHOM",
    "WHNASPRO",
    "WNASMEAL",
    "WHNASFIN",
    "NASTRANS"
]

df = df[df[need_vars].eq(1).any(axis=1)].copy()

print(len(df))
# Out:
# 3227

# %%
soc_away_activity_cols = [
    "SOC3AWYA",
    "SOC3AWYB",
    "SOC3AWYC",
    "SOC3AWYD",
    "SOC3AWYE",
    "SOC3AWYF",
    "SOC3AWYG",
    "SOC3AWYH",
    "SOC3AWYI",
    "SOC3AWYJ",
    "SOC3AWYK"
]
soc_home_activity_cols = [
    "SOCL3MA",
    "SOCL3MB",
    "SOCL3MC",
    "SOCL3MD",
    "SOCL3ME",
    "SOCL3MF",
]

# %%
#convert them to binary
for col in soc_away_activity_cols:
    df[col] = (df[col] != 0).astype(int)

for col in soc_home_activity_cols:
    df[col] = (df[col] != 0).astype(int)

# %%
for col in soc_away_activity_cols + soc_home_activity_cols:
    print(col, df[col].value_counts().to_dict())
# Out:
# SOC3AWYA {1: 2530, 0: 697}
# SOC3AWYB {1: 2123, 0: 1104}
# SOC3AWYC {0: 2509, 1: 718}
# SOC3AWYD {0: 2809, 1: 418}
# SOC3AWYE {0: 3020, 1: 207}
# SOC3AWYF {0: 2945, 1: 282}
# SOC3AWYG {0: 2655, 1: 572}
# SOC3AWYH {0: 2664, 1: 563}
# SOC3AWYI {0: 2764, 1: 463}
# SOC3AWYJ {0: 3187, 1: 40}
# SOC3AWYK {0: 3174, 1: 53}
# SOCL3MA {1: 2862, 0: 365}
# SOCL3MB {1: 2905, 0: 322}
# SOCL3MC {0: 2929, 1: 298}
# SOCL3MD {0: 3000, 1: 227}
# SOCL3ME {0: 3076, 1: 151}
# SOCL3MF {0: 3088, 1: 139}

# %%
df["SOCAWAYCOUNT"] = (
    df[soc_away_activity_cols]
    .sum(axis=1)
    .astype(int)
)

df["SOCHOMECOUNT"] = (
    df[soc_home_activity_cols]
    .sum(axis=1)
    .astype(int)
)

# %%
print(df["SOCAWAYCOUNT"].value_counts().sort_index())
print()

print(df["SOCHOMECOUNT"].value_counts().sort_index())
# Out:
# SOCAWAYCOUNT
# 0    328
# 1    582
# 2    868
# 3    696
# 4    405
# 5    204
# 6     95
# 7     40
# 8      8
# 9      1
# Name: count, dtype: int64
#
# SOCHOMECOUNT
# 0     109
# 1     390
# 2    2142
# 3     460
# 4     104
# 5      20
# 6       2
# Name: count, dtype: int64

# %%
df["SOCPARTICIPATIONTYPE"] = (
    (df["SOCAWAYCOUNT"] > 0).astype(int) +
    (df["SOCHOMECOUNT"] > 0).astype(int)
)

# %%
print(df.columns.tolist())
# Out:
# ['ABSPID', 'ABSFID', 'ABSHID', 'ABSIID', 'POPESTAB', 'RECLPSN', 'FINWTP', 'AGEPC', 'SEX', 'EDLVLATB', 'ARIAC', 'SPENGPRO', 'SOCMORCO', 'K10CATEG', 'DISBSTAT', 'SFHEALTH', 'RASFRICO', 'RASFRIMO', 'RASFRISC', 'RASFRIEM', 'RASFRIHC', 'RASFRIHO', 'RASFRIME', 'RASFRIPM', 'RASFRIPA', 'RASFRITR', 'WHNASMOB', 'RASEXMOB', 'WHNASSCR', 'RASEXSC', 'WHNASCOM', 'RASEXCOM', 'NAHCFCAR', 'RASEXHC', 'WHNASEMO', 'RASEXGUI', 'WHNASHOM', 'RASEXHOM', 'WHNASPRO', 'RASEXPRP', 'WNASMEAL', 'RASEXMEA', 'WHNASFIN', 'RASEXPAP', 'NASTRANS', 'RASEXTRA', 'SOC3AWYA', 'SOC3AWYB', 'SOC3AWYC', 'SOC3AWYD', 'SOC3AWYE', 'SOC3AWYF', 'SOC3AWYG', 'SOC3AWYH', 'SOC3AWYI', 'SOC3AWYJ', 'SOC3AWYK', 'SOC3AWYL', 'SOC3AWYM', 'SOC3AWYN', 'SOCL3MA', 'SOCL3MB', 'SOCL3MC', 'SOCL3MD', 'SOCL3ME', 'SOCL3MF', 'SOCL3MG', 'SOCL3MH', 'WPM0101', 'WPM0102', 'WPM0103', 'WPM0104', 'WPM0105', 'WPM0106', 'WPM0107', 'WPM0108', 'WPM0109', 'WPM0110', 'WPM0111', 'WPM0112', 'WPM0113', 'WPM0114', 'WPM0115', 'WPM0116', 'WPM0117', 'WPM0118', 'WPM0119', 'WPM0120', 'WPM0121', 'WPM0122', 'WPM0123', 'WPM0124', 'WPM0125', 'WPM0126', 'WPM0127', 'WPM0128', 'WPM0129', 'WPM0130', 'WPM0131', 'WPM0132', 'WPM0133', 'WPM0134', 'WPM0135', 'WPM0136', 'WPM0137', 'WPM0138', 'WPM0139', 'WPM0140', 'WPM0141', 'WPM0142', 'WPM0143', 'WPM0144', 'WPM0145', 'WPM0146', 'WPM0147', 'WPM0148', 'WPM0149', 'WPM0150', 'WPM0151', 'WPM0152', 'WPM0153', 'WPM0154', 'WPM0155', 'WPM0156', 'WPM0157', 'WPM0158', 'WPM0159', 'WPM0160', 'WPM0101.1', 'WPM0102.1', 'WPM0103.1', 'WPM0104.1', 'WPM0105.1', 'WPM0106.1', 'WPM0107.1', 'WPM0108.1', 'WPM0109.1', 'WPM0110.1', 'WPM0111.1', 'WPM0112.1', 'WPM0113.1', 'WPM0114.1', 'WPM0115.1', 'WPM0116.1', 'WPM0117.1', 'WPM0118.1', 'WPM0119.1', 'WPM0120.1', 'WPM0121.1', 'WPM0122.1', 'WPM0123.1', 'WPM0124.1', 'WPM0125.1', 'WPM0126.1', 'WPM0127.1', 'WPM0128.1', 'WPM0129.1', 'WPM0130.1', 'WPM0131.1', 'WPM0132.1', 'WPM0133.1', 'WPM0134.1', 'WPM0135.1', 'WPM0136.1', 'WPM0137.1', 'WPM0138.1', 'WPM0139.1', 'WPM0140.1', 'WPM0141.1', 'WPM0142.1', 'WPM0143.1', 'WPM0144.1', 'WPM0145.1', 'WPM0146.1', 'WPM0147.1', 'WPM0148.1', 'WPM0149.1', 'WPM0150.1', 'WPM0151.1', 'WPM0152.1', 'WPM0153.1', 'WPM0154.1', 'WPM0155.1', 'WPM0156.1', 'WPM0157.1', 'WPM0158.1', 'WPM0159.1', 'WPM0160.1', 'HHNOPSNB', 'INCDECHD', '_merge', 'SOCAWAYCOUNT', 'SOCHOMECOUNT', 'SOCPARTICIPATIONTYPE']

# %%
duplicate_wpm_cols = [
    col for col in df.columns
    if col.startswith("WPM") and col.endswith(".1")
]

print("Duplicate WPM columns:", len(duplicate_wpm_cols))
df = df.drop(columns=duplicate_wpm_cols)
# Out:
# Duplicate WPM columns: 60

# %%
print(df.columns.tolist())
# Out:
# ['ABSPID', 'ABSFID', 'ABSHID', 'ABSIID', 'POPESTAB', 'RECLPSN', 'FINWTP', 'AGEPC', 'SEX', 'EDLVLATB', 'ARIAC', 'SPENGPRO', 'SOCMORCO', 'K10CATEG', 'DISBSTAT', 'SFHEALTH', 'RASFRICO', 'RASFRIMO', 'RASFRISC', 'RASFRIEM', 'RASFRIHC', 'RASFRIHO', 'RASFRIME', 'RASFRIPM', 'RASFRIPA', 'RASFRITR', 'WHNASMOB', 'RASEXMOB', 'WHNASSCR', 'RASEXSC', 'WHNASCOM', 'RASEXCOM', 'NAHCFCAR', 'RASEXHC', 'WHNASEMO', 'RASEXGUI', 'WHNASHOM', 'RASEXHOM', 'WHNASPRO', 'RASEXPRP', 'WNASMEAL', 'RASEXMEA', 'WHNASFIN', 'RASEXPAP', 'NASTRANS', 'RASEXTRA', 'SOC3AWYA', 'SOC3AWYB', 'SOC3AWYC', 'SOC3AWYD', 'SOC3AWYE', 'SOC3AWYF', 'SOC3AWYG', 'SOC3AWYH', 'SOC3AWYI', 'SOC3AWYJ', 'SOC3AWYK', 'SOC3AWYL', 'SOC3AWYM', 'SOC3AWYN', 'SOCL3MA', 'SOCL3MB', 'SOCL3MC', 'SOCL3MD', 'SOCL3ME', 'SOCL3MF', 'SOCL3MG', 'SOCL3MH', 'WPM0101', 'WPM0102', 'WPM0103', 'WPM0104', 'WPM0105', 'WPM0106', 'WPM0107', 'WPM0108', 'WPM0109', 'WPM0110', 'WPM0111', 'WPM0112', 'WPM0113', 'WPM0114', 'WPM0115', 'WPM0116', 'WPM0117', 'WPM0118', 'WPM0119', 'WPM0120', 'WPM0121', 'WPM0122', 'WPM0123', 'WPM0124', 'WPM0125', 'WPM0126', 'WPM0127', 'WPM0128', 'WPM0129', 'WPM0130', 'WPM0131', 'WPM0132', 'WPM0133', 'WPM0134', 'WPM0135', 'WPM0136', 'WPM0137', 'WPM0138', 'WPM0139', 'WPM0140', 'WPM0141', 'WPM0142', 'WPM0143', 'WPM0144', 'WPM0145', 'WPM0146', 'WPM0147', 'WPM0148', 'WPM0149', 'WPM0150', 'WPM0151', 'WPM0152', 'WPM0153', 'WPM0154', 'WPM0155', 'WPM0156', 'WPM0157', 'WPM0158', 'WPM0159', 'WPM0160', 'HHNOPSNB', 'INCDECHD', '_merge', 'SOCAWAYCOUNT', 'SOCHOMECOUNT', 'SOCPARTICIPATIONTYPE']

# %%
wpm_cols = [f"WPM{i:04d}" for i in range(101, 161)]

column_order = [
    "ABSPID",
    "ABSFID",
    "ABSHID",
    "ABSIID",
    "POPESTAB",
    "FINWTP",
    "RECLPSN",

    *wpm_cols,

    "AGEPC",
    "SEX",
    "EDLVLATB",
    "INCDECHD",
    "ARIAC",
    "SPENGPRO",
    "HHNOPSNB",
    
    "SOCAWAYCOUNT",
    "SOCHOMECOUNT",
    "SOCPARTICIPATIONTYPE",
    "SOCMORCO",

    "K10CATEG",
    "DISBSTAT",
    "SFHEALTH",

    "RASFRICO",
    "RASFRIMO",
    "RASFRISC",
    "RASFRIEM",
    "RASFRIHC",
    "RASFRIHO",
    "RASFRIME",
    "RASFRIPM",
    "RASFRIPA",
    "RASFRITR",

    "WHNASMOB",
    "WHNASSCR",
    "WHNASCOM",
    "NAHCFCAR",
    "WHNASEMO",
    "WHNASHOM",
    "WHNASPRO",
    "WNASMEAL",
    "WHNASFIN",
    "NASTRANS",

    "RASEXMOB",
    "RASEXSC",
    "RASEXCOM",
    "RASEXHC",
    "RASEXGUI",
    "RASEXHOM",
    "RASEXPRP",
    "RASEXMEA",
    "RASEXPAP",
    "RASEXTRA",
]
df = df[column_order]

# %%
df.to_csv(
    "sdac2018processed.csv",
    index=False
)
print(df.shape)
# Out:
# (3227, 111)
